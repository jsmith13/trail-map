# %% [markdown]
# Generate plots of trailhead locations and metrics.

# %%
# import required libraries
import config
import pandas as pd
import numpy as np
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as plgo

# set Plotly to display inline plots
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# load the dataset
hikes = pd.read_csv("hiking project - NWtrails (1).csv")

# display head
hikes.head()
# Out:
#    Hike_ID  ascent  descent difficulty  high  latitude  length  \
# 0        1    1671    -1672  blueBlack  3266   45.9627     4.5
# 1        2     710     -699       blue   761   45.9311     2.6
# 2        3     168     -300  greenBlue   311   45.9196     1.1
# 3        4     180     -115  greenBlue   550   45.8468     1.6
# 4        5      44       -5      green    51   46.1211     1.1
#
#                location  longitude   low                              name  \
# 0       Seaside, Oregon  -123.6899  1704             Saddle Mountain Trail
# 1  Cannon Beach, Oregon  -123.9785    50                Clatsop Loop Trail
# 2  Cannon Beach, Oregon  -123.9743    40  OCT: Ecola Point to Indian Beach
# 3  Cannon Beach, Oregon  -123.7623   398              Soapstone Lake Trail
# 4     Warrenton, Oregon  -123.8767    10               Netul Landing Trail
#
#    starVotes  stars                                            summary  \
# 0         16    4.6  This is perhaps the best hike on the west coas...
# 1         13    4.3  Work your way through a coastal rain forest to...
# 2          6    3.5  A forested tral with occasional views of the o...
# 3          2    3.5                                      Needs Summary
# 4          1    2.0  A flat, even trail along the river from a park...
#
#                                                  url
# 0  https://www.hikingproject.com/trail/7047615/sa...
# 1  https://www.hikingproject.com/trail/7025215/cl...
# 2  https://www.hikingproject.com/trail/7012607/oc...
# 3  https://www.hikingproject.com/trail/7050277/so...
# 4  https://www.hikingproject.com/trail/7056781/ne...

# %% [markdown]
# #### Filter By
# - length
# - high
# - ascent
# - difficulty
# - rating
#
# #### Geography Plot
# - longitude
# - latitude
# - difficulty
# - name
#
# #### Metrics Plot
# - length
# - ascent
#
# #### Selected Trail Information
# - name
# - difficulty
# - length
# - ascent
# - descent
# - summary
# - url
# - stars
# - starVotes

# %%
## plot map of trailheads

# define data assignments
data = [dict(
    type = "scattermapbox",
    lon = hikes["longitude"],
    lat = hikes["latitude"], 
    text = hikes["name"],
    mode = "markers"
)]

# define plot layout
layout = plgo.Layout(
    title = "Hikes", 
    autosize = False,
    width = 800,
    height = 800,
    
    # map location and orientation
    mapbox = plgo.layout.Mapbox(
        accesstoken = config.mapbox_api_key,
        bearing = 0,
        center = plgo.layout.mapbox.Center(
            lon = np.mean([hikes["longitude"].min(), hikes["longitude"].max()]),
            lat = np.mean([hikes["latitude"].min(), hikes["latitude"].max()])
        ),
    
        # map perspective
        pitch = 0,
        zoom = 6
    )
)

# show plot
iplot({"data": data, "layout": layout})
# Out:
# <div>
#
#
#             <div id="b79a43c8-8679-4a3b-b201-eb2bc1954805" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById
        colorscale = [[0.0, "green"], [0.5, "blue"], [1.0, "black"]]
    )
)]

# define plot layout
layout = plgo.Layout(
    title = "Hikes",
    autosize = False,
    width = 800,
    height = 800,
    
    # define axis parameters
    xaxis = dict(
        type = "log",
        title = "distance (miles)"
    ),
    
    yaxis = dict(
        type = "log",
        title = "elevation gain (feet)"
    )
)

# show plot
iplot({"data": data, "layout": layout})
# Out:
# <div>
#
#
#             <div id="ab3b5290-d43c-44eb-9ee0-4be2c0385d3c" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ab3b5290-d43c-44eb-9ee0-4be2c0385d3c")) {
#                     Plotly.newPlot(
#                         'ab3b5290-d43c-44eb-9ee0-4be2c0385d3c',
#                         [{"marker": {"color": [3, 2, 1, 1, 0, 1, 0, 0, 0, 0, 0, 4, 4, 2, 4, 5, 4, 3, 3, 4, 1, 1, 4, 2, 3, 4, 2, 4, 2, 2, 4, 4, 2, 1, 3, 4, 1, 4, 4, 0, 4, 2, 2, 0, 0, 0, 2, 4, 3, 2, 5, 3, 2, 4, 1, 2, 3, 3, 4, 0, 3, 4, 3, 4, 4, 1, 2, 2, 2, 2, 1, 1, 2, 2, 0, 2, 2, 0, 1, 4, 2, 0, 4, 4, 0, 4, 0, 0, 0, 4, 2, 0, 1, 2, 2, 3, 2, 2, 1, 1, 1, 0, 4, 4, 2, 3, 1, 4, 0, 1, 2, 4, 1, 1, 2, 4, 1, 1, 4, 3, 3, 1, 2, 2, 2, 4, 2, 0, 1, 1, 3, 0, 0, 0, 1, 0, 5, 2, 2, 2, 3, 2, 4, 3, 3, 3, 5, 3, 4, 3, 4, 4, 3, 4, 4, 4, 2, 4, 2, 2, 2, 4, 4, 4, 4, 3, 1, 0, 4, 3, 2, 0, 3, 3, 1, 0, 4, 2, 4, 4, 3, 4, 0, 2, 4, 3, 1, 4, 4, 4, 4, 4, 4, 3, 4, 4, 3, 4, 1, 2, 4, 2, 4, 2, 2, 1, 0, 0, 0, 0, 0, 4, 4, 0, 0, 3, 3, 4, 2, 1, 2, 3, 3, 2, 2, 2, 2, 4, 4, 4, 4, 2, 4, 2, 4, 4, 3, 3, 4, 4, 4, 2, 1, 0, 4, 3, 2, 4, 3, 4, 4, 4, 1, 3, 2, 2, 4, 4, 4, 2, 4, 2, 4, 1, 2, 1, 2, 0, 4, 2, 0, 3, 2, 0, 3, 4, 4, 3, 4, 2, 1, 4, 2, 3, 2, 0, 2, 2, 1, 2, 1, 1, 4, 4, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 1, 2, 4, 2, 4, 3, 2, 3, 1, 2, 2, 3, 5, 2, 2, 3, 1, 4, 1, 3, 2, 2, 3, 2, 2, 2, 4, 4, 4, 0, 2, 4, 3, 2, 0, 4, 4, 4, 4, 0, 2, 4, 4, 3, 4, 4, 4, 4, 1, 5, 2, 4, 1, 1,